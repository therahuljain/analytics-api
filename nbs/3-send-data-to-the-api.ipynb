# %%
import requests

path = "/api/events"
base_url = "http://localhost:8080"
endpoint = f"{base_url}{path}"
endpoint
# Out:
# 'http://localhost:8080/api/events'

# %%
data = {"page": "/test+"}

# %%
import json

json.dumps(data)
# Out:
# '{"page": "/test+"}'

# %%
headers = {
    "Content-Type": "application/json"
}
response = requests.post(endpoint, data = json.dumps(data))
print(response.headers)
# Out:
# {'date': 'Sat, 11 Apr 2026 21:40:04 GMT', 'server': 'uvicorn', 'content-length': '10', 'content-type': 'application/json'}

# %%
print ('ok', response.ok)
if response.ok:   
    data = response.json()
    print(data, type(data), data.get('results'))
# Out:
# ok True
# {'id': 123} <class 'dict'> None

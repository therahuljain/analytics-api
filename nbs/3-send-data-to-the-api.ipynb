# %%
import requests

import json

path = "/api/events"
base_url = "http://localhost:8080"
endpoint = f"{base_url}{path}"
endpoint
# Out:
# 'http://localhost:8080/api/events'

# %%
path = "/api/events/"
base_url = "http://localhost:8080"
create_endpoint = f"{base_url}{path}"

response = requests.post(create_endpoint, json={
    "page": "/test+",
    "description": "something"
})
print(response.headers)
print ('ok', response.ok)
if response.ok:   
    data = response.json()
    print(data, type(data), data.get('items'))
else:
    print(response.text)
# Out:
# {'date': 'Mon, 13 Apr 2026 22:00:18 GMT', 'server': 'uvicorn', 'content-length': '21', 'content-type': 'text/plain; charset=utf-8'}
# ok False
# Internal Server Error

# %%
detail_path = "/api/events/12"
detail_endpoint = f"{base_url}{detail_path}"
headers = {
    "Content-Type": "application/json"
}
response = requests.put(detail_endpoint, json={ "description": "hello world"}) # HTTP PUT
print(response.headers)
print ('ok', response.ok)
if response.ok:   
    data = response.json()
    print(data, type(data), data.get('results'))
else:
    print(response.text)
# Out:
# {'date': 'Mon, 13 Apr 2026 19:51:28 GMT', 'server': 'uvicorn', 'content-length': '47', 'content-type': 'application/json'}
# ok True
# {'id': 12, 'page': '', 'description': 'hello world'} <class 'dict'> None
